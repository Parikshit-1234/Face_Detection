# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import dlib

# %%
os.chdir('D:\\AIML\\EXTRACTED\\PROJECTS\\project\\Project\\PRJ Face Detection\\Data Set')
image = cv2.imread("people1.jpg")
display (image.shape)
# Out:
# (1280, 1920, 3)

# %%
plt.imshow(image)
plt.show()

# %%
print(image)
# Out:
# [[[ 91 103 107]
#   [102 114 118]
#   [ 92 107 110]
#   ...
#   [187 192 193]
#   [186 191 192]
#   [185 190 191]]
#
#  [[ 93 105 109]
#   [ 97 109 113]
#   [ 95 110 113]
#   ...
#   [187 192 193]
#   [186 191 192]
#   [185 190 191]]
#
#  [[ 96 111 114]
#   [ 96 111 114]
#   [102 117 120]
#   ...
#   [186 191 192]
#   [185 190 191]
#   [184 189 190]]
#
#  ...
#
#  [[ 48  43  40]
#   [ 46  41  38]
#   [ 44  39  36]
#   ...
#   [251 248 244]
#   [252 247 244]
#   [251 246 243]]
#
#  [[ 55  49  44]
#   [ 53  47  42]
#   [ 49  43  38]
#   ...
#   [251 248 244]
#   [252 247 244]
#   [252 247 244]]
#
#  [[ 56  50  45]
#   [ 54  48  43]
#   [ 50  44  39]
#   ...
#   [252 249 245]
#   [253 248 245]
#   [253 248 245]]]

# %%
cv2.imshow('', image)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
image = cv2.resize(image, (800, 600))

image.shape
# Out:
# (600, 800, 3)

# %%
cv2.imshow('',image)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow('',image_gray)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
display (image_gray.shape)
# Out:
# (600, 800)

# %%
face_detector = cv2.CascadeClassifier('D:\\AIML\\EXTRACTED\\PROJECTS\\project\\Project\\PRJ Face Detection\\Cascades\\haarcascade_frontalface_default.xml')
display (face_detector)
# Out:
# < cv2.CascadeClassifier 000001F6694DB5F0>

# %%
detections = face_detector.detectMultiScale(image_gray)
display (detections)
# Out:
# array([[390, 323,  56,  56],
#        [387, 233,  73,  73],
#        [ 92, 239,  66,  66],
#        [115, 124,  53,  53],
#        [475, 123,  59,  59],
#        [677,  72,  68,  68]])

# %%
display (len(detections))
# Out:
# 6

# %%
x=390  # X - Co ordinates 
y=323  # Y- Co ordinates 
w=56   # Face Width
h=56   # Face Height 
cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 1)
cv2.imshow('', image_gray)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
x=115  # X - Co ordinates 
y=124  # Y- Co ordinates 
w=52   # Face Width
h=52   # Face Height 
cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 5)
cv2.imshow('', image_gray)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
x=475  # X - Co ordinates 
y=123  # Y- Co ordinates 
w=59   # Face Width
h=59  # Face Height 
cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 5)
cv2.imshow('', image_gray)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
for (x, y, w, h) in detections:
  cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 5)
cv2.imshow('', image_gray)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
image = cv2.imread('D:\\AIML\\EXTRACTED\\PROJECTS\\project\\Project\\PRJ Face Detection\\Data Set\\people1.jpg')
display (image.shape)
image = cv2.resize(image, (800, 600)) # Resize image
display (image.shape) 
detections = face_detector.detectMultiScale(image)
display (detections)
# Out:
# (1280, 1920, 3)
# (600, 800, 3)
# array([[390, 323,  56,  56],
#        [387, 233,  73,  73],
#        [ 92, 239,  66,  66],
#        [115, 124,  53,  53],
#        [475, 123,  59,  59],
#        [677,  72,  68,  68]])

# %%
for (x, y, w, h) in detections:
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,255), 5)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
image = cv2.imread('D:\\AIML\\EXTRACTED\\PROJECTS\\project\\Project\\PRJ Face Detection\\Data Set\\people1.jpg')
image = cv2.resize(image, (800, 600)) # Resize image
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.09)
display (detections)
for (x, y, w, h) in detections:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 5)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# array([[386, 232,  74,  74],
#        [ 90, 238,  69,  69],
#        [113, 122,  56,  56],
#        [475, 122,  60,  60],
#        [678,  74,  65,  65]])

# %%
image = cv2.imread('D:\\AIML\\EXTRACTED\\PROJECTS\\project\\Project\\PRJ Face Detection\\Data Set\\people2.jpg')
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
image = cv2.imread('D:\\AIML\\EXTRACTED\\PROJECTS\\project\\Project\\PRJ Face Detection\\Data Set\\people2.jpg')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.09)
display (detections)
for (x, y, w, h) in detections:
    print(w, h)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# array([[461, 367,  33,  33],
#        [692, 153,  44,  44],
#        [424,  32,  46,  46],
#        [663,  83,  43,  43],
#        [ 91,  81,  50,  50],
#        [600,  61,  49,  49],
#        [168,  35,  50,  50],
#        [907,  63,  50,  50],
#        [479,  69,  47,  47],
#        [462, 378,  27,  27],
#        [324,  49,  45,  45],
#        [235,  45,  51,  51],
#        [825,  90,  51,  51],
#        [380,  53,  54,  54],
#        [718, 101,  44,  44]])
# 33 33
# 44 44
# 46 46
# 43 43
# 50 50
# 49 49
# 50 50
# 50 50
# 47 47
# 27 27
# 45 45
# 51 51
# 51 51
# 54 54
# 44 44

# %%
image = cv2.imread('D:\\AIML\\EXTRACTED\\PROJECTS\\project\\Project\\PRJ Face Detection\\Data Set\\people2.jpg')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.2,
                                            minNeighbors=7,minSize=(20,20), maxSize=(100,100))
display (detections)
for (x, y, w, h) in detections:
    print(w, h)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# array([[424,  31,  47,  47],
#        [168,  35,  49,  49],
#        [662,  83,  44,  44],
#        [906,  63,  51,  51],
#        [480,  70,  47,  47],
#        [ 91,  81,  51,  51],
#        [825,  91,  51,  51],
#        [717, 100,  46,  46],
#        [321,  48,  47,  47],
#        [234,  46,  50,  50],
#        [380,  54,  52,  52],
#        [600,  60,  49,  49]])
# 47 47
# 49 49
# 44 44
# 51 51
# 47 47
# 51 51
# 51 51
# 46 46
# 47 47
# 50 50
# 52 52
# 49 49

# %%
eye_detector= cv2.CascadeClassifier('D:\\AIML\\EXTRACTED\\PROJECTS\\project\\Project\\PRJ Face Detection\\Cascades\\haarcascade_eye.xml')

display (eye_detector)
# Out:
# < cv2.CascadeClassifier 000001F6694DB750>

# %%
image = cv2.imread('D:\\AIML\\EXTRACTED\\PROJECTS\\project\\Project\\PRJ Face Detection\\Data Set\\people1.jpg')
display (image.shape)

image = cv2.resize(image, (1600,1000)) # Resize image
print(image.shape)
face_detections = face_detector.detectMultiScale(image, scaleFactor = 1.3, minSize = (30,30))
for (x, y, w, h) in face_detections:
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)

eye_detections = eye_detector.detectMultiScale(image, scaleFactor = 1.1, minNeighbors=10, maxSize=(60,60))

for (x, y, w, h) in eye_detections:
  print(w, h)
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,0,255), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# (1280, 1920, 3)
# (1000, 1600, 3)
# 33 33
# 25 25
# 33 33
# 31 31
# 22 22
# 30 30
# 23 23
# 22 22
# 29 29

# %%
car_detector = cv2.CascadeClassifier('D:\\AIML\\EXTRACTED\\PROJECTS\\project\\Project\\PRJ Face Detection\\Cascades\\cars.xml')

display (car_detector)
# Out:
# < cv2.CascadeClassifier 000001F6694DB6D0>

# %%
image = cv2.imread('D:\\AIML\\EXTRACTED\\PROJECTS\\project\\Project\\PRJ Face Detection\\Data Set\\car.jpg')
display (image.shape)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# (286, 468, 3)

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = car_detector.detectMultiScale(image_gray, scaleFactor = 1.03, minNeighbors=8)                                      
for (x, y, w, h) in detections:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
clock_detector = cv2.CascadeClassifier('D:\AIML\EXTRACTED\PROJECTS\project\Project\PRJ Face Detection\Cascades\clocks.xml')
display (clock_detector)
# Out:
# < cv2.CascadeClassifier 000001F6694DA130>

# %%
image = cv2.imread('D:\\AIML\\EXTRACTED\\PROJECTS\\project\\Project\\PRJ Face Detection\\Data Set\\clock.jpg')
display (image.shape)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# (438, 450, 3)

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = clock_detector.detectMultiScale(image_gray, scaleFactor = 1.03, minNeighbors=1)                                      
for (x, y, w, h) in detections:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
full_detector  = cv2.CascadeClassifier('D:\\AIML\\EXTRACTED\\PROJECTS\\project\\Project\\PRJ Face Detection\\Cascades\\fullbody.xml')
display (full_detector)
# Out:
# < cv2.CascadeClassifier 000001F6694DB950>

# %%
image = cv2.imread('D:\\AIML\\EXTRACTED\\PROJECTS\\project\\Project\\PRJ Face Detection\\Data Set\\people3.jpg')
display (image.shape)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# (294, 626, 3)

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = full_detector.detectMultiScale(image_gray,scaleFactor = 1.05, minNeighbors=5, minSize = (50,50)) 
for (x, y, w, h) in detections:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
image = cv2.imread('D:\\AIML\\EXTRACTED\\PROJECTS\\project\\Project\\PRJ Face Detection\\Data Set\\people2.jpg')
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
face_detector_hog = dlib.get_frontal_face_detector()
detections = face_detector_hog(image, 1)

# %%
display (len(detections))
display (detections)
# Out:
# 14
# rectangles[[(429, 38) (465, 74)], [(665, 90) (701, 126)], [(717, 103) (760, 146)], [(909, 70) (952, 113)], [(828, 98) (871, 142)], [(605, 70) (641, 106)], [(777, 62) (813, 98)], [(485, 78) (521, 114)], [(386, 60) (429, 103)], [(170, 41) (213, 84)], [(93, 89) (136, 132)], [(237, 50) (280, 94)], [(323, 50) (367, 94)], [(544, 65) (588, 108)]]

# %%
print(detections[0])
print(detections[0].left())
print(detections[0].top())
print(detections[0].right())
print(detections[0].bottom())
cv2.rectangle(image, (detections[0].left(), detections[0].top()), (detections[0].right(), detections[0].bottom()), (0, 255, 255), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# [(429, 38) (465, 74)]
# 429
# 38
# 465
# 74

# %%
for face in detections:
  l, t, r, b = face.left(), face.top(), face.right(), face.bottom()
  cv2.rectangle(image, (l, t), (r, b), (0, 255, 255), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
image = cv2.imread('D:\\AIML\\EXTRACTED\\PROJECTS\\project\\Project\\PRJ Face Detection\\Data Set\\people2.jpg')
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()

# %%
cnn_detector = dlib.cnn_face_detection_model_v1('D:\\AIML\\EXTRACTED\\PROJECTS\\project\\Project\\PRJ Face Detection\\Weights\\mmod_human_face_detector.dat')
display (cnn_detector)

# %%
detections = cnn_detector(image, 1)
for face in detections:
  l, t, r, b, c = face.rect.left(), face.rect.top(), face.rect.right(), face.rect.bottom(), face.confidence
  print(c)
  cv2.rectangle(image, (l, t), (r, b), (255, 255, 0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
# Out:
# 1.1440682411193848
# 1.137049913406372
# 1.1278996467590332
# 1.1200228929519653
# 1.1149370670318604
# 1.1131553649902344
# 1.097571611404419
# 1.0942120552062988
# 1.085314154624939
# 1.0801892280578613
# 1.0800764560699463
# 1.0784764289855957
# 1.0664036273956299
# 1.0641793012619019

# %%
image = cv2.imread('D:\\AIML\\EXTRACTED\\PROJECTS\\project\\Project\\PRJ Face Detection\\Data Set\\people3.jpg')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
haarcascade_detector = cv2.CascadeClassifier('D:\\AIML\\EXTRACTED\\PROJECTS\\project\\Project\\PRJ Face Detection\\Cascades\\haarcascade_frontalface_default.xml')
detections = haarcascade_detector.detectMultiScale(image_gray, scaleFactor = 1.001, minNeighbors=5, minSize = (5,5))
for (x, y, w, h) in detections:
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
cv2.imshow('',image)
cv2.waitKey(10000)
plt.show()
cv2.destroyAllWindows()
